# %%
from IPython.display import Image

# %% [markdown]
# <b>Працюємо у віруальному середовищі у Jupyter Lab
# (https://docs.jupyter.org/en/latest/)
#
# <b style="color:green">pip3 install venv </b>#Створити віртуальне середовище
#
# <b style="color:green">python3 -m venv env </b>#Створити віртуальне середовище
#
# <b style="color:green">source env/bin/activate </b>#запустити віртуальне середовище (для MacOS, Ubuntu) <br>
# <b style="color:green">env/Scripts/activate.ps1 </b>#запустити віртуальне середовище (для Windows)
#
# <b style="color:green">pip install jupyterlab </b>#встановити jupyter lab в віртуальне середовище
#
# <b style="color:green">jupyter lab </b>#запустити jupyter lab

# %% [markdown]
# ### Трохи основ пайтону

# %% [markdown]
# Глобальний репозиторій пакунків (https://pypi.org/)

# %%
Image(url="Screenshot at Jun 06 11-10-01.png", width=800, height=500,)
# Out:
# <img src="Screenshot at Jun 06 11-10-01.png" width="800" height="500"/>

# %%
Image(url="Screenshot at Jun 06 11-14-28.png", width=800, height=500,)
# Out:
# <img src="Screenshot at Jun 06 11-14-28.png" width="800" height="500"/>

# %%
Image(url="Screenshot at Jun 06 12-22-37.png", width=800, height=500,)
# Out:
# <img src="Screenshot at Jun 06 12-22-37.png" width="800" height="500"/>

# %% [markdown]
# <b>Бібліотеки</b>
#
# pandas (https://pandas.pydata.org/pandas-docs/stable/index.html) <br>
# seaborn (https://seaborn.pydata.org/)

# %%
#встановлення бібліотек із jupyter lab
# !pip install pandas seaborn
# Out:
# Requirement already satisfied: pandas in ./env/lib/python3.10/site-packages (2.0.2)
# Requirement already satisfied: seaborn in ./env/lib/python3.10/site-packages (0.12.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./env/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in ./env/lib/python3.10/site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in ./env/lib/python3.10/site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in ./env/lib/python3.10/site-packages (from pandas) (1.24.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in ./env/lib/python3.10/site-packages (from seaborn) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in ./env/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in ./env/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in ./env/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.39.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./env/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in ./env/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in ./env/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./env/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: six>=1.5 in ./env/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
#Імпортування бібліотек

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Досліджуємо датасет

# %% [markdown]
# Набір даних Lego <br>
# (https://www.kaggle.com/datasets/rtatman/lego-database?select=sets.csv)

# %%
pd.read_csv('lego/themes.csv')
# Out:
#       id                   name  parent_id
# 0      1                Technic        NaN
# 1      2         Arctic Technic        1.0
# 2      3            Competition        1.0
# 3      4         Expert Builder        1.0
# 4      5                  Model        1.0
# ..   ...                    ...        ...
# 609  610             Brickheadz        NaN
# 610  611  Series 17 Minifigures      535.0
# 611  612    Star Wars Episode 8      158.0
# 612  613             Freemakers      158.0
# 613  614                 Jungle       52.0
#
# [614 rows x 3 columns]

# %%
df = pd.read_csv('lego/themes.csv')

# %%
df
# Out:
#       id                   name  parent_id
# 0      1                Technic        NaN
# 1      2         Arctic Technic        1.0
# 2      3            Competition        1.0
# 3      4         Expert Builder        1.0
# 4      5                  Model        1.0
# ..   ...                    ...        ...
# 609  610             Brickheadz        NaN
# 610  611  Series 17 Minifigures      535.0
# 611  612    Star Wars Episode 8      158.0
# 612  613             Freemakers      158.0
# 613  614                 Jungle       52.0
#
# [614 rows x 3 columns]

# %%
df['name'].to_list()
# Out:
# ['Technic',
#  'Arctic Technic',
#  'Competition',
#  'Expert Builder',
#  'Model',
#  'Airport',
#  'Construction',
#  'Farm',
#  'Fire',
#  'Harbor',
#  'Off-Road',
#  'Race',
#  'Riding Cycle',
#  'Robot',
#  'Traffic',
#  'RoboRiders',
#  'Speed Slammers',
#  'Star Wars',
#  'Supplemental',
#  'Throwbot Slizer',
#  'Universal Building Set',
#  'Creator',
#  'Basic Model',
#  'Airport',
#  'Castle',
#  'Construction',
#  'Race',
#  'Harbor',
#  'Train',
#  'Traffic',
#  'Creature',
#  'Robot',
#  'Food & Drink',
#  'Building',
#  'Cargo',
#  'Fire',
#  'Basic Set',
#  'Model',
#  'Traffic',
#  'Creature',
#  'Riding Cycle',
#  'Airport',
#  'Building',
#  'Recreation',
#  'Cargo',
#  'Harbor',
#  'Fire',
#  'Supplemental',
#  'Mecha',
#  'Town',
#  'Arctic',
#  'City',
#  'Airport',
#  'Cargo',
#  'Coast Guard',
#  'Construction',
#  'Farm',
#  'Fire',
#  'Harbor',
#  'Hospital',
#  'Police',
#  'Supplemental',
#  'Traffic',
#  'Off-Road',
#  'Arctic',
#  'Trains',
#  'Classic Town',
#  'Airport',
#  'Building',
#  'Cargo',
#  'Coast Guard',
#  'Construction',
#  'Farm',
#  'Fire',
#  'Food & Drink',
#  'Station',
#  'Harbor',
#  'Hospital',
#  'Off-Road',
#  'Police',
#  'Post Office',
#  'Race',
#  'Recreation',
#  'Supplemental',
#  'Traffic',
#  'Divers',
#  'Extreme Team',
#  'Launch Command',
#  'Outback',
#  'Paradisa',
#  'Race',
#  'Res-Q',
#  'Space Port',
#  'Town Jr.',
#  'Cargo',
#  'Coast Guard',
#  'Construction',
#  'Fire',
#  'Gas Station',
#  'Police',
#  'Race',
#  'Supplemental',
#  'Traffic',
#  'Town Plan',
#  'World City',
#  'Airport',
#  'Coast Guard',
#  'Fire',
#  'Food & Drink',
#  'Harbor',
#  'Police',
#  'Racers',
#  'Drome Racers',
#  'Ferrari',
#  'Lamborghini',
#  'Power Racers',
#  'Radio Control',
#  'Speed Racer',
#  'Supplemental',
#  'Tiny Turbos',
#  'Track System',
#  'Williams F1',
#  'World Racers',
#  'Supplemental',
#  'Xalax',
#  'Space',
#  'Alien Conquest',
#  'Blacktron I',
#  'Blacktron II',
#  'Classic Space',
#  'Exploriens',
#  'Futuron',
#  'Ice Planet 2002',
#  'Insectoids',
#  'Life On Mars',
#  'M:Tron',
#  'Mars Mission',
#  'RoboForce',
#  'Space Police I',
#  'Space Police II',
#  'Space Police III',
#  'Spyrius',
#  'Supplemental',
#  'UFO',
#  'Unitron',
#  'Galaxy Squad',
#  'Pirates',
#  'Pirates I',
#  'Imperial Armada',
#  'Imperial Guards',
#  'Imperial Soldiers',
#  'Islanders',
#  'Pirates II',
#  'Pirates III',
#  'Modular Buildings',
#  'Mini',
#  'Bricktober',
#  'Star Wars',
#  'Mini',
#  'Star Wars Clone Wars',
#  'Star Wars Episode 2',
#  'Star Wars Episode 3',
#  'Star Wars Episode 4/5/6',
#  'Star Wars Episode 1',
#  'Star Wars Clone Wars',
#  'Star Wars Episode 1',
#  'Star Wars Episode 2',
#  'Star Wars Episode 3',
#  'Star Wars Episode 4/5/6',
#  'Star Wars Other',
#  'Ultimate Collector Series',
#  'Star Wars Episode 1',
#  'Star Wars Episode 3',
#  'Star Wars Episode 4/5/6',
#  'Star Wars Episode 2',
#  'Planet Series 1',
#  'Planet Series 2',
#  'Minifig Pack',
#  'Planet Series 3',
#  'Planet Series 4',
#  'Star Wars Episode 4/5/6',
#  'Star Wars Rebels',
#  'Star Wars Expanded Universe',
#  'Star Wars Episode 7',
#  'Star Wars Rogue One',
#  'Castle',
#  'Black Falcons',
#  'Black Knights',
#  'Classic Castle',
#  'Crusaders',
#  'Dark Forest',
#  'Dragon Knights',
#  'Fantasy Era',
#  'Forestmen',
#  'Fright Knights',
#  'Kingdoms',
#  'Knights Kingdom I',
#  'Knights Kingdom II',
#  'Lion Knights',
#  'My Own Creation',
#  'Royal Knights',
#  'Supplemental',
#  'Wolfpack',
#  'Designer Sets',
#  'Building',
#  'Seasonal',
#  'Advent',
#  'City',
#  'Star Wars',
#  'Belville',
#  'Castle',
#  'Classic Basic',
#  'Clikits',
#  'Creator',
#  'Pirates',
#  'Friends',
#  'Advent Sub-Set',
#  'Belville',
#  'Castle',
#  'City',
#  'Classic Basic',
#  'Clikits',
#  'Creator',
#  'Pirates',
#  'Star Wars',
#  'Friends',
#  'Christmas',
#  'Creator',
#  'Easter',
#  'Halloween',
#  'Thanksgiving',
#  'Valentine',
#  'Train',
#  '12V',
#  '4.5V',
#  '9V',
#  'My Own Creation',
#  'My Own Train',
#  'World City',
#  'RC Train',
#  'Supplemental',
#  '12V',
#  '4.5V',
#  '9V',
#  'RC Train',
#  'Harry Potter',
#  'Chamber of Secrets',
#  'Goblet of Fire',
#  'Order of the Phoenix',
#  'Prisoner of Azkaban',
#  "Sorcerer's Stone",
#  'Architecture',
#  'Skylines',
#  'Bulk Bricks',
#  'Castle',
#  'Technic',
#  'Train',
#  'Mindstorms',
#  'NXT',
#  'RCX',
#  'Star Wars',
#  'EV3',
#  'Pirates of the Caribbean',
#  'Indiana Jones',
#  'Kingdom of the Crystal Skull',
#  'Last Crusade',
#  'Raiders of the Lost Ark',
#  'Temple of Doom',
#  'Cars',
#  'Ben 10',
#  'Prince of Persia',
#  'SpongeBob SquarePants',
#  'Studios',
#  'Jurassic Park III',
#  'Toy Story',
#  'Sculptures',
#  'Mosaic',
#  'Model Team',
#  '4 Juniors',
#  'Jack Stone',
#  'Police',
#  'Airport',
#  'Fire',
#  'Traffic',
#  'Gas Station',
#  'Pirates',
#  'Spider-Man',
#  'Spider-Man 2',
#  'Supplemental',
#  'Town',
#  'Police',
#  'Traffic',
#  'Construction',
#  'Gas Station',
#  'Fire',
#  'Adventurers',
#  'Desert',
#  'Dino Island',
#  'Jungle',
#  'Orient Expedition',
#  'Other',
#  'Agents',
#  'Ultra Agents',
#  'Alpha Team',
#  'Mission Deep Sea',
#  'Mission Deep Freeze',
#  'Aquazone',
#  'Aquanauts',
#  'Aquaraiders I',
#  'Aquaraiders II',
#  'Aquasharks',
#  'Hydronauts',
#  'Stingrays',
#  'Supplemental',
#  'Atlantis',
#  'Mini',
#  'Avatar',
#  'Belville',
#  'Fairy-Tale',
#  'Golden Land',
#  'Hospital',
#  'Playhouse',
#  'Recreation',
#  'Bionicle',
#  'Agori',
#  'Barraki',
#  'Battle Vehicles',
#  'Bohrok',
#  'Bohrok Va',
#  'Bohrok-Kal',
#  'Glatorian',
#  'Glatorian Legends',
#  'Matoran of Light',
#  'Matoran of Mahri Nui',
#  'Matoran of Mata Nui',
#  'Matoran of Metru Nui',
#  'Matoran of Voya Nui',
#  'Mistika',
#  'Phantoka',
#  'Piraka',
#  'Playsets',
#  'Rahaga',
#  'Rahi',
#  'Rahkshi',
#  'Stars',
#  'Supplemental',
#  'Titans',
#  'Toa',
#  'Toa Hagah',
#  'Toa Hordika',
#  'Toa Inika',
#  'Toa Mahri',
#  'Toa Metru',
#  'Toa Nuva',
#  'Tohunga',
#  'Turaga',
#  'Vahki',
#  'Visorak',
#  'Warriors',
#  'Protectors',
#  'Skull Spiders',
#  'Toa Okoto',
#  'Boat',
#  'Building Set with People',
#  'Classic',
#  'Basic Set',
#  'Building',
#  'HO 1:87 Vehicles',
#  'Jumbo Bricks',
#  'Mosaic',
#  'Supplemental',
#  'Town Plan',
#  'Vehicle',
#  'Airport',
#  'Farm',
#  'Fire',
#  'Harbor',
#  'Traffic',
#  'Supplemental',
#  'Train',
#  'Construction',
#  'Cargo',
#  'Wooden Box Set',
#  'Dino 2010',
#  'Dino Attack',
#  'Dinosaurs',
#  'Discovery',
#  "Disney's Mickey Mouse",
#  'Exo-Force',
#  'Fabuland',
#  'Hospital',
#  'Post Office',
#  'Harbor',
#  'Airport',
#  'Fire',
#  'Police',
#  'Factory',
#  'FIRST LEGO League',
#  'Freestyle',
#  'Hero Factory',
#  'Heroes',
#  'Vehicles',
#  'Villains',
#  'Hobby Sets',
#  'Homemaker',
#  'Inventor',
#  'Island Xtreme Stunts',
#  'LEGO Brand Store',
#  'Monthly Mini Model Build',
#  'Pick A Model',
#  'Legoland',
#  'Airport',
#  'Building',
#  'Castle',
#  'Coast Guard',
#  'Construction',
#  'Fire',
#  'Gas Station',
#  'Harbor',
#  'Hospital',
#  'Police',
#  'Space',
#  'Vehicle',
#  'Western',
#  'Legoland Parks',
#  'Bionicle',
#  'Holiday',
#  'Christmas',
#  'Halloween',
#  'Pirates',
#  'Star Wars',
#  'Master Building Academy',
#  'Minitalia',
#  'Ninja',
#  'Ninjago',
#  'Airjitzu',
#  "Pharaoh's Quest",
#  'Power Functions',
#  'Power Miners',
#  'Primo',
#  'Quatro',
#  'Rock Raiders',
#  'Service Packs',
#  'Adventurers',
#  'Aquazone',
#  'Belville',
#  'Castle',
#  'Fabuland',
#  'Pirates',
#  'Primo',
#  'Scala',
#  'Space',
#  'Technic',
#  'Town',
#  'Classic Town',
#  'Train',
#  'Western\xa0',
#  'Sports',
#  'Basketball',
#  'Gravity Games',
#  'Hockey',
#  'Soccer',
#  'Spybiotics',
#  'Time Cruisers',
#  'Universal Building Set',
#  'Airport',
#  'Basic',
#  'Basic Model',
#  'Basic Set',
#  'Classic Basic',
#  'Ferries',
#  'Gears',
#  'Supplemental',
#  'Vikings',
#  'Western',
#  'Cowboys',
#  'Indians',
#  'X-Pod',
#  'Creator',
#  'Znap',
#  'Dino',
#  'Super Heroes',
#  'Guardians of the Galaxy',
#  'Batman',
#  'Ultimate Collector Series',
#  'Justice League',
#  'Avengers',
#  'Spider-Man',
#  'Superman',
#  'Iron Man',
#  'X-Men',
#  'Constraction',
#  'Marvel',
#  'Friends',
#  'Jungle Rescue',
#  'Animals',
#  'Books',
#  'Technic',
#  'Train',
#  'Clikits',
#  'Gear',
#  'Game',
#  'Key Chain',
#  'Duplo',
#  'Basic Set',
#  'Cars',
#  'Educational and Dacta',
#  '4 Juniors',
#  'Adventurers',
#  'Boat',
#  'Building Set with People',
#  'Castle',
#  'Classic',
#  'Creator',
#  'Dinosaurs',
#  'Explore',
#  'Learning',
#  'Mindstorms',
#  'NXT',
#  'RCX',
#  'WeDo',
#  'Primo',
#  'Samsonite',
#  'Service Packs',
#  'Technic',
#  'Soft Bricks',
#  'Space',
#  'Supplemental',
#  'Technic',
#  'Control Lab',
#  'eLAB',
#  'Supplemental',
#  'Town',
#  'Universal Building Set',
#  'Collectible Minifigures',
#  'Series 1 Minifigures',
#  'Series 2 Minifigures',
#  'Series 3 Minifigures',
#  'Series 4 Minifigures',
#  'Series 5 Minifigures',
#  'Series 6 Minifigures',
#  'Series 7 Minifigures',
#  'Series 8 Minifigures',
#  'Series 9 Minifigures',
#  'Series 10 Minifigures',
#  'Team GB',
#  'Series 11 Minifigures',
#  'Series 12 Minifigures',
#  'The LEGO Movie Series',
#  'The Simpsons',
#  'Series 13 Minifigures',
#  'Series 14 Minifigures',
#  'The Simpsons Series 2',
#  'Series 15 Minifigures',
#  'Disney',
#  'Series 16 Minifigures',
#  'DFB Minifigures',
#  'Monster Fighters',
#  'Value Packs',
#  'Universe',
#  'The Hobbit and Lord of the Rings',
#  'The Hobbit',
#  'An Unexpected Journey',
#  'The Desolation of Smaug',
#  'The Battle of the Five Armies',
#  'The Lord of the Rings',
#  'The Fellowship of the Ring',
#  'The Two Towers',
#  'The Return of the King',
#  'Teenage Mutant Ninja Turtles',
#  'Legends of Chima',
#  'Speedorz',
#  'Constraction',
#  'Legend Beasts',
#  'The Lone Ranger',
#  'LEGO Ideas and CUUSOO',
#  'Minecraft',
#  'The LEGO Movie',
#  'Disney Princess',
#  'Mixels',
#  'Series 1',
#  'Series 2',
#  'Series 3',
#  'Series 4',
#  'Series 5',
#  'Series 6',
#  'Series 7',
#  'Series 8',
#  'Series 9',
#  'Fusion',
#  'Juniors',
#  'DC Comics Super Heroes',
#  'Disney Princess',
#  'Fantasy',
#  'Friends',
#  'Marvel Super Heroes',
#  'Nijago',
#  'Promotional',
#  'LEGO Exclusive',
#  'Elves',
#  'Speed Champions',
#  'Jurassic World',
#  'Scooby-Doo',
#  'Dimensions',
#  'Nexo Knights',
#  'Angry Birds',
#  'Ghostbusters',
#  'Disney',
#  'The LEGO Batman Movie',
#  'Brickheadz',
#  'Series 17 Minifigures',
#  'Star Wars Episode 8',
#  'Freemakers',
#  'Jungle']

# %%
df['name'].unique()
# Out:
# array(['Technic', 'Arctic Technic', 'Competition', 'Expert Builder',
#        'Model', 'Airport', 'Construction', 'Farm', 'Fire', 'Harbor',
#        'Off-Road', 'Race', 'Riding Cycle', 'Robot', 'Traffic',
#        'RoboRiders', 'Speed Slammers', 'Star Wars', 'Supplemental',
#        'Throwbot Slizer', 'Universal Building Set', 'Creator',
#        'Basic Model', 'Castle', 'Train', 'Creature', 'Food & Drink',
#        'Building', 'Cargo', 'Basic Set', 'Recreation', 'Mecha', 'Town',
#        'Arctic', 'City', 'Coast Guard', 'Hospital', 'Police', 'Trains',
#        'Classic Town', 'Station', 'Post Office', 'Divers', 'Extreme Team',
#        'Launch Command', 'Outback', 'Paradisa', 'Res-Q', 'Space Port',
#        'Town Jr.', 'Gas Station', 'Town Plan', 'World City', 'Racers',
#        'Drome Racers', 'Ferrari', 'Lamborghini', 'Power Racers',
#        'Radio Control', 'Speed Racer', 'Tiny Turbos', 'Track System',
#        'Williams F1', 'World Racers', 'Xalax', 'Space', 'Alien Conquest',
#        'Blacktron I', 'Blacktron II', 'Classic Space', 'Exploriens',
#        'Futuron', 'Ice Planet 2002', 'Insectoids', 'Life On Mars',
#        'M:Tron', 'Mars Mission', 'RoboForce', 'Space Police I',
#        'Space Police II', 'Space Police III', 'Spyrius', 'UFO', 'Unitron',
#        'Galaxy Squad', 'Pirates', 'Pirates I', 'Imperial Armada',
#        'Imperial Guards', 'Imperial Soldiers', 'Islanders', 'Pirates II',
#        'Pirates III', 'Modular Buildings', 'Mini', 'Bricktober',
#        'Star Wars Clone Wars', 'Star Wars Episode 2',
#        'Star Wars Episode 3', 'Star Wars Episode 4/5/6',
#        'Star Wars Episode 1', 'Star Wars Other',
#        'Ultimate Collector Series', 'Planet Series 1', 'Planet Series 2',
#        'Minifig Pack', 'Planet Series 3', 'Planet Series 4',
#        'Star Wars Rebels', 'Star Wars Expanded Universe',
#        'Star Wars Episode 7', 'Star Wars Rogue One', 'Black Falcons',
#        'Black Knights', 'Classic Castle', 'Crusaders', 'Dark Forest',
#        'Dragon Knights', 'Fantasy Era', 'Forestmen', 'Fright Knights',
#        'Kingdoms', 'Knights Kingdom I', 'Knights Kingdom II',
#        'Lion Knights', 'My Own Creation', 'Royal Knights', 'Wolfpack',
#        'Designer Sets', 'Seasonal', 'Advent', 'Belville', 'Classic Basic',
#        'Clikits', 'Friends', 'Advent Sub-Set', 'Christmas', 'Easter',
#        'Halloween', 'Thanksgiving', 'Valentine', '12V', '4.5V', '9V',
#        'My Own Train', 'RC Train', 'Harry Potter', 'Chamber of Secrets',
#        'Goblet of Fire', 'Order of the Phoenix', 'Prisoner of Azkaban',
#        "Sorcerer's Stone", 'Architecture', 'Skylines', 'Bulk Bricks',
#        'Mindstorms', 'NXT', 'RCX', 'EV3', 'Pirates of the Caribbean',
#        'Indiana Jones', 'Kingdom of the Crystal Skull', 'Last Crusade',
#        'Raiders of the Lost Ark', 'Temple of Doom', 'Cars', 'Ben 10',
#        'Prince of Persia', 'SpongeBob SquarePants', 'Studios',
#        'Jurassic Park III', 'Toy Story', 'Sculptures', 'Mosaic',
#        'Model Team', '4 Juniors', 'Jack Stone', 'Spider-Man',
#        'Spider-Man 2', 'Adventurers', 'Desert', 'Dino Island', 'Jungle',
#        'Orient Expedition', 'Other', 'Agents', 'Ultra Agents',
#        'Alpha Team', 'Mission Deep Sea', 'Mission Deep Freeze',
#        'Aquazone', 'Aquanauts', 'Aquaraiders I', 'Aquaraiders II',
#        'Aquasharks', 'Hydronauts', 'Stingrays', 'Atlantis', 'Avatar',
#        'Fairy-Tale', 'Golden Land', 'Playhouse', 'Bionicle', 'Agori',
#        'Barraki', 'Battle Vehicles', 'Bohrok', 'Bohrok Va', 'Bohrok-Kal',
#        'Glatorian', 'Glatorian Legends', 'Matoran of Light',
#        'Matoran of Mahri Nui', 'Matoran of Mata Nui',
#        'Matoran of Metru Nui', 'Matoran of Voya Nui', 'Mistika',
#        'Phantoka', 'Piraka', 'Playsets', 'Rahaga', 'Rahi', 'Rahkshi',
#        'Stars', 'Titans', 'Toa', 'Toa Hagah', 'Toa Hordika', 'Toa Inika',
#        'Toa Mahri', 'Toa Metru', 'Toa Nuva', 'Tohunga', 'Turaga', 'Vahki',
#        'Visorak', 'Warriors', 'Protectors', 'Skull Spiders', 'Toa Okoto',
#        'Boat', 'Building Set with People', 'Classic', 'HO 1:87 Vehicles',
#        'Jumbo Bricks', 'Vehicle', 'Wooden Box Set', 'Dino 2010',
#        'Dino Attack', 'Dinosaurs', 'Discovery', "Disney's Mickey Mouse",
#        'Exo-Force', 'Fabuland', 'Factory', 'FIRST LEGO League',
#        'Freestyle', 'Hero Factory', 'Heroes', 'Vehicles', 'Villains',
#        'Hobby Sets', 'Homemaker', 'Inventor', 'Island Xtreme Stunts',
#        'LEGO Brand Store', 'Monthly Mini Model Build', 'Pick A Model',
#        'Legoland', 'Western', 'Legoland Parks', 'Holiday',
#        'Master Building Academy', 'Minitalia', 'Ninja', 'Ninjago',
#        'Airjitzu', "Pharaoh's Quest", 'Power Functions', 'Power Miners',
#        'Primo', 'Quatro', 'Rock Raiders', 'Service Packs', 'Scala',
#        'Western\xa0', 'Sports', 'Basketball', 'Gravity Games', 'Hockey',
#        'Soccer', 'Spybiotics', 'Time Cruisers', 'Basic', 'Ferries',
#        'Gears', 'Vikings', 'Cowboys', 'Indians', 'X-Pod', 'Znap', 'Dino',
#        'Super Heroes', 'Guardians of the Galaxy', 'Batman',
#        'Justice League', 'Avengers', 'Superman', 'Iron Man', 'X-Men',
#        'Constraction', 'Marvel', 'Jungle Rescue', 'Animals', 'Books',
#        'Gear', 'Game', 'Key Chain', 'Duplo', 'Educational and Dacta',
#        'Explore', 'Learning', 'WeDo', 'Samsonite', 'Soft Bricks',
#        'Control Lab', 'eLAB', 'Collectible Minifigures',
#        'Series 1 Minifigures', 'Series 2 Minifigures',
#        'Series 3 Minifigures', 'Series 4 Minifigures',
#        'Series 5 Minifigures', 'Series 6 Minifigures',
#        'Series 7 Minifigures', 'Series 8 Minifigures',
#        'Series 9 Minifigures', 'Series 10 Minifigures', 'Team GB',
#        'Series 11 Minifigures', 'Series 12 Minifigures',
#        'The LEGO Movie Series', 'The Simpsons', 'Series 13 Minifigures',
#        'Series 14 Minifigures', 'The Simpsons Series 2',
#        'Series 15 Minifigures', 'Disney', 'Series 16 Minifigures',
#        'DFB Minifigures', 'Monster Fighters', 'Value Packs', 'Universe',
#        'The Hobbit and Lord of the Rings', 'The Hobbit',
#        'An Unexpected Journey', 'The Desolation of Smaug',
#        'The Battle of the Five Armies', 'The Lord of the Rings',
#        'The Fellowship of the Ring', 'The Two Towers',
#        'The Return of the King', 'Teenage Mutant Ninja Turtles',
#        'Legends of Chima', 'Speedorz', 'Legend Beasts', 'The Lone Ranger',
#        'LEGO Ideas and CUUSOO', 'Minecraft', 'The LEGO Movie',
#        'Disney Princess', 'Mixels', 'Series 1', 'Series 2', 'Series 3',
#        'Series 4', 'Series 5', 'Series 6', 'Series 7', 'Series 8',
#        'Series 9', 'Fusion', 'Juniors', 'DC Comics Super Heroes',
#        'Fantasy', 'Marvel Super Heroes', 'Nijago', 'Promotional',
#        'LEGO Exclusive', 'Elves', 'Speed Champions', 'Jurassic World',
#        'Scooby-Doo', 'Dimensions', 'Nexo Knights', 'Angry Birds',
#        'Ghostbusters', 'The LEGO Batman Movie', 'Brickheadz',
#        'Series 17 Minifigures', 'Star Wars Episode 8', 'Freemakers'],
#       dtype=object)

# %% [markdown]
# <b>Основні інструменти опису даних</b><br>
# <b style="color:green">head(n)</b>: Повертає перші 'n' рядків з DataFrame. За замовчуванням 'n' дорівнює 5.<br>
# <b style="color:green">tail(n)</b>: Повертає останні 'n' рядків з DataFrame. За замовчуванням 'n' дорівнює 5.<br>
# <b style="color:green">describe()</b>: Повертає статистичний опис даних для кожного числового стовпця.<br>
# <b style="color:green">info()</b>: Повертає інформацію про DataFrame, включаючи кількість рядків, тип даних кожного стовпця, кількість ненульових значень і споживання пам'яті.<br>
# <b style="color:green">dtypes</b>: Повертає типи даних кожного стовпця.<br>
# <b style="color:green">shape</b>: Повертає форму датафрейму як кортеж (кількість рядків, кількість стовпців).<br>
# <b style="color:green">columns</b>: Повертає імена стовпців DataFrame.<br>
# <b style="color:green">value_counts()</b>: Повертає серію, яка містить кількості унікальних значень.<br>
# <b style="color:green">sort_values(by=column_name)</b>: Сортує DataFrame за значеннями в певному стовпці.<br>
# <b style="color:green">corr()</b>: Повертає кореляційну матрицю для числових стовпців в DataFrame.<br>
# <b style="color:green">isnull()</b>: Повертає DataFrame, де True позначає пропущені значення, а False - непропущені значення.<br>

# %%
df['parent_id'].unique()
# Out:
# array([ nan,   1.,   5.,  22.,  23.,  38.,  50.,  52.,  67.,  94., 105.,
#        112., 123., 126., 147., 148., 155., 158., 159., 171., 180., 186.,
#        204., 206., 207., 217., 227., 233., 236., 241., 246., 252., 254.,
#        258., 264., 273., 276., 279., 280., 287., 290., 296., 302., 304.,
#        307., 315., 318., 324., 365., 373., 390., 400., 408., 411., 425.,
#        435., 443., 454., 458., 465., 475., 478., 482., 484., 494., 497.,
#        501., 504., 507., 518., 524., 529., 535., 561., 562., 566., 571.,
#        580., 591.])

# %%
df.shape
# Out:
# (614, 3)

# %%
df
# Out:
#       id                   name  parent_id
# 0      1                Technic        NaN
# 1      2         Arctic Technic        1.0
# 2      3            Competition        1.0
# 3      4         Expert Builder        1.0
# 4      5                  Model        1.0
# ..   ...                    ...        ...
# 609  610             Brickheadz        NaN
# 610  611  Series 17 Minifigures      535.0
# 611  612    Star Wars Episode 8      158.0
# 612  613             Freemakers      158.0
# 613  614                 Jungle       52.0
#
# [614 rows x 3 columns]

# %%
df['id'] = df['id'].astype(str)
df['parent_id'] = df['parent_id'].astype(str)

# %%
df.describe()
# Out:
#          id          name parent_id
# count   614           614       614
# unique  614           402        79
# top       1  Supplemental       nan
# freq      1            18       111

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         614 non-null    object
#  1   name       614 non-null    object
#  2   parent_id  614 non-null    object
# dtypes: object(3)
# memory usage: 14.5+ KB

# %%
df.columns
# Out:
# Index(['id', 'name', 'parent_id'], dtype='object')

# %% [markdown]
# #### дізнаємось теми по роках

# %%
sets = pd.read_csv('lego/sets.csv')
sets['theme_id'] = sets['theme_id'].astype(str)

# %%
Image(url="4zjxm.png", width=800, height=500,)
# Out:
# <img src="4zjxm.png" width="800" height="500"/>

# %%
sets.merge(df, how = 'left', left_on = 'theme_id', right_on = 'id', suffixes = ['_theme', '_themes'])
# Out:
#              set_num                                         name_theme  year  \
# 0               00-1                                    Weetabix Castle  1970
# 1             0011-2                                  Town Mini-Figures  1978
# 2             0011-3                         Castle 2 for 1 Bonus Offer  1987
# 3             0012-1                                 Space Mini-Figures  1979
# 4             0013-1                                 Space Mini-Figures  1979
# ...              ...                                                ...   ...
# 11668    Wauwatosa-1  LEGO Store Grand Opening Exclusive Set, Mayfai...  2012
# 11669   WHITEHOUSE-1                                  Micro White House  2015
# 11670    Wiesbaden-1  LEGO Store Grand Opening Exclusive Set, Wiesba...  2010
# 11671  WishingWell-1                     Wishing Well [Toys R Us Promo]  2013
# 11672        wwgp1-1                Wild West Limited Edition Gift Pack  1996
#
#       theme_id  num_parts   id       name_themes parent_id
# 0          414        471  414            Castle     411.0
# 1           84         12   84      Supplemental      67.0
# 2          199          2  199      Lion Knights     186.0
# 3          143         12  143      Supplemental     126.0
# 4          143         12  143      Supplemental     126.0
# ...        ...        ...  ...               ...       ...
# 11668      408         15  408  LEGO Brand Store       nan
# 11669      598         59  598       Promotional       nan
# 11670      408        146  408  LEGO Brand Store       nan
# 11671      494         28  494           Friends       nan
# 11672      476          3  476           Cowboys     475.0
#
# [11673 rows x 8 columns]

# %%
df = sets.merge(df, how = 'left', left_on = 'theme_id', right_on = 'id', suffixes = ['_theme', '_themes'])

# %%
df[df['year'].isna()]
# Out:
# Empty DataFrame
# Columns: [set_num, name_theme, year, theme_id, num_parts, id, name_themes, parent_id]
# Index: []

# %%
# Перетворення року в строку
df['year'] = df['year'].astype(int).astype(str)

# Додавання дня і місяця до року
df['year'] = '01-01-' + df['year']

# Перетворення року в формат дати
df['year'] = pd.to_datetime(df['year'])

# %%
df
# Out:
#              set_num                                         name_theme  \
# 0               00-1                                    Weetabix Castle
# 1             0011-2                                  Town Mini-Figures
# 2             0011-3                         Castle 2 for 1 Bonus Offer
# 3             0012-1                                 Space Mini-Figures
# 4             0013-1                                 Space Mini-Figures
# ...              ...                                                ...
# 11668    Wauwatosa-1  LEGO Store Grand Opening Exclusive Set, Mayfai...
# 11669   WHITEHOUSE-1                                  Micro White House
# 11670    Wiesbaden-1  LEGO Store Grand Opening Exclusive Set, Wiesba...
# 11671  WishingWell-1                     Wishing Well [Toys R Us Promo]
# 11672        wwgp1-1                Wild West Limited Edition Gift Pack
#
#             year theme_id  num_parts   id       name_themes parent_id
# 0     1970-01-01      414        471  414            Castle     411.0
# 1     1978-01-01       84         12   84      Supplemental      67.0
# 2     1987-01-01      199          2  199      Lion Knights     186.0
# 3     1979-01-01      143         12  143      Supplemental     126.0
# 4     1979-01-01      143         12  143      Supplemental     126.0
# ...          ...      ...        ...  ...               ...       ...
# 11668 2012-01-01      408         15  408  LEGO Brand Store       nan
# 11669 2015-01-01      598         59  598       Promotional       nan
# 11670 2010-01-01      408        146  408  LEGO Brand Store       nan
# 11671 2013-01-01      494         28  494           Friends       nan
# 11672 1996-01-01      476          3  476           Cowboys     475.0
#
# [11673 rows x 8 columns]

# %%
df[df['name_theme'].isin(['Space Mini-Figures', 'Wild West Limited Edition Gift Pack'])]
# Out:
#   set_num          name_theme       year theme_id  num_parts   id  \
# 3  0012-1  Space Mini-Figures 1979-01-01      143         12  143
# 4  0013-1  Space Mini-Figures 1979-01-01      143         12  143
# 5  0014-1  Space Mini-Figures 1979-01-01      143         12  143
# 6  0015-1  Space Mini-Figures 1979-01-01      143         18  143
#
#     name_themes parent_id
# 3  Supplemental     126.0
# 4  Supplemental     126.0
# 5  Supplemental     126.0
# 6  Supplemental     126.0

# %%
# Метод зведених таблиць - pd.pivot_table()
# https://pandas.pydata.org/docs/reference/api/pandas.pivot_table.html
grouped = pd.pivot_table(df[['year', 'name_themes']], index = ['year'], aggfunc = 'count')

# %%
grouped
# Out:
#             name_themes
# year
# 1950-01-01            7
# 1953-01-01            4
# 1954-01-01           14
# 1955-01-01           28
# 1956-01-01           12
# ...                 ...
# 2013-01-01          593
# 2014-01-01          713
# 2015-01-01          665
# 2016-01-01          596
# 2017-01-01          296
#
# [66 rows x 1 columns]

# %%
grouped.reset_index(inplace = True)

# %%
grouped
# Out:
#          year  name_themes
# 0  1950-01-01            7
# 1  1953-01-01            4
# 2  1954-01-01           14
# 3  1955-01-01           28
# 4  1956-01-01           12
# ..        ...          ...
# 61 2013-01-01          593
# 62 2014-01-01          713
# 63 2015-01-01          665
# 64 2016-01-01          596
# 65 2017-01-01          296
#
# [66 rows x 2 columns]

# %%
grouped['year'] = grouped['year'].dt.year

# %%
# стовпчикова діаграма: https://seaborn.pydata.org/generated/seaborn.barplot.html
sns.barplot(data=grouped, x="year", y="name_themes")
# Out:
# <Axes: xlabel='year', ylabel='name_themes'>

# %%
sns.barplot(data=grouped, x="year", y="name_themes", errorbar = None)
# Out:
# <Axes: xlabel='year', ylabel='name_themes'>

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})

bar = sns.barplot(data=grouped, x="year", y="name_themes", errorbar = None)
bar.bar_label(bar.containers[0], fmt='%.1f')
bar.set_xticklabels(bar.get_xticklabels(), rotation=90)
# Out:
# [Text(0, 0, '1950'),
#  Text(1, 0, '1953'),
#  Text(2, 0, '1954'),
#  Text(3, 0, '1955'),
#  Text(4, 0, '1956'),
#  Text(5, 0, '1957'),
#  Text(6, 0, '1958'),
#  Text(7, 0, '1959'),
#  Text(8, 0, '1960'),
#  Text(9, 0, '1961'),
#  Text(10, 0, '1962'),
#  Text(11, 0, '1963'),
#  Text(12, 0, '1964'),
#  Text(13, 0, '1965'),
#  Text(14, 0, '1966'),
#  Text(15, 0, '1967'),
#  Text(16, 0, '1968'),
#  Text(17, 0, '1969'),
#  Text(18, 0, '1970'),
#  Text(19, 0, '1971'),
#  Text(20, 0, '1972'),
#  Text(21, 0, '1973'),
#  Text(22, 0, '1974'),
#  Text(23, 0, '1975'),
#  Text(24, 0, '1976'),
#  Text(25, 0, '1977'),
#  Text(26, 0, '1978'),
#  Text(27, 0, '1979'),
#  Text(28, 0, '1980'),
#  Text(29, 0, '1981'),
#  Text(30, 0, '1982'),
#  Text(31, 0, '1983'),
#  Text(32, 0, '1984'),
#  Text(33, 0, '1985'),
#  Text(34, 0, '1986'),
#  Text(35, 0, '1987'),
#  Text(36, 0, '1988'),
#  Text(37, 0, '1989'),
#  Text(38, 0, '1990'),
#  Text(39, 0, '1991'),
#  Text(40, 0, '1992'),
#  Text(41, 0, '1993'),
#  Text(42, 0, '1994'),
#  Text(43, 0, '1995'),
#  Text(44, 0, '1996'),
#  Text(45, 0, '1997'),
#  Text(46, 0, '1998'),
#  Text(47, 0, '1999'),
#  Text(48, 0, '2000'),
#  Text(49, 0, '2001'),
#  Text(50, 0, '2002'),
#  Text(51, 0, '2003'),
#  Text(52, 0, '2004'),
#  Text(53, 0, '2005'),
#  Text(54, 0, '2006'),
#  Text(55, 0, '2007'),
#  Text(56, 0, '2008'),
#  Text(57, 0, '2009'),
#  Text(58, 0, '2010'),
#  Text(59, 0, '2011'),
#  Text(60, 0, '2012'),
#  Text(61, 0, '2013'),
#  Text(62, 0, '2014'),
#  Text(63, 0, '2015'),
#  Text(64, 0, '2016'),
#  Text(65, 0, '2017')]

# %%
grouped_df = df[['year','name_themes']]

# %%
grouped_df
# Out:
#             year       name_themes
# 0     1970-01-01            Castle
# 1     1978-01-01      Supplemental
# 2     1987-01-01      Lion Knights
# 3     1979-01-01      Supplemental
# 4     1979-01-01      Supplemental
# ...          ...               ...
# 11668 2012-01-01  LEGO Brand Store
# 11669 2015-01-01       Promotional
# 11670 2010-01-01  LEGO Brand Store
# 11671 2013-01-01           Friends
# 11672 1996-01-01           Cowboys
#
# [11673 rows x 2 columns]

# %%
grouped_df['year'] = pd.to_datetime(grouped_df['year']).dt.year
# Out:
# /var/folders/m9/3hdt_fjs2q5f8zpd_k15lc400000gn/T/ipykernel_41360/2944764285.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   grouped_df['year'] = pd.to_datetime(grouped_df['year']).dt.year

# %%
df_count = grouped_df.groupby(['year', 'name_themes']).size().reset_index(name='counts')
df_count
# Out:
#       year   name_themes  counts
# 0     1950     Basic Set       1
# 1     1950  Supplemental       6
# 2     1953  Supplemental       4
# 3     1954  Supplemental      12
# 4     1954     Town Plan       2
# ...    ...           ...     ...
# 2091  2017  Super Heroes       9
# 2092  2017      Superman       1
# 2093  2017       Technic      11
# 2094  2017       Traffic       3
# 2095  2017     Valentine       1
#
# [2096 rows x 3 columns]

# %%
df_count = pd.pivot_table(df_count, index = 'year', columns = 'name_themes', aggfunc = 'sum')
df_count
# Out:
#             counts                                                       \
# name_themes    12V 4 Juniors 4.5V  9V Advent Advent Sub-Set Adventurers
# year
# 1950           NaN       NaN  NaN NaN    NaN            NaN         NaN
# 1953           NaN       NaN  NaN NaN    NaN            NaN         NaN
# 1954           NaN       NaN  NaN NaN    NaN            NaN         NaN
# 1955           NaN       NaN  NaN NaN    NaN            NaN         NaN
# 1956           NaN       NaN  NaN NaN    NaN            NaN         NaN
# ...            ...       ...  ...  ..    ...            ...         ...
# 2013           NaN       NaN  NaN NaN    NaN            NaN         NaN
# 2014           NaN       NaN  NaN NaN    NaN            NaN         NaN
# 2015           NaN       NaN  NaN NaN    NaN            NaN         NaN
# 2016           NaN       NaN  NaN NaN    1.0            NaN         NaN
# 2017           NaN       NaN  NaN NaN    NaN            NaN         NaN
#
#                                    ...                                      \
# name_themes Agents Agori Airjitzu  ... Williams F1 Wolfpack Wooden Box Set
# year                               ...
# 1950           NaN   NaN      NaN  ...         NaN      NaN            NaN
# 1953           NaN   NaN      NaN  ...         NaN      NaN            NaN
# 1954           NaN   NaN      NaN  ...         NaN      NaN            NaN
# 1955           NaN   NaN      NaN  ...         NaN      NaN            NaN
# 1956           NaN   NaN      NaN  ...         NaN      NaN            NaN
# ...            ...   ...      ...  ...         ...      ...            ...
# 2013           NaN   NaN      NaN  ...         NaN      NaN            NaN
# 2014           NaN   NaN      NaN  ...         NaN      NaN            NaN
# 2015           NaN   NaN      6.0  ...         NaN      NaN            NaN
# 2016           NaN   NaN      1.0  ...         NaN      NaN            NaN
# 2017           NaN   NaN      NaN  ...         NaN      NaN            NaN
#
#
# name_themes World City World Racers X-Men X-Pod Xalax Znap eLAB
# year
# 1950               NaN          NaN   NaN   NaN   NaN  NaN  NaN
# 1953               NaN          NaN   NaN   NaN   NaN  NaN  NaN
# 1954               NaN          NaN   NaN   NaN   NaN  NaN  NaN
# 1955               NaN          NaN   NaN   NaN   NaN  NaN  NaN
# 1956               NaN          NaN   NaN   NaN   NaN  NaN  NaN
# ...                ...          ...   ...   ...   ...  ...  ...
# 2013               NaN          NaN   NaN   NaN   NaN  NaN  NaN
# 2014               NaN          NaN   1.0   NaN   NaN  NaN  NaN
# 2015               NaN          NaN   NaN   NaN   NaN  NaN  NaN
# 2016               NaN          NaN   NaN   NaN   NaN  NaN  NaN
# 2017               NaN          NaN   NaN   NaN   NaN  NaN  NaN
#
# [66 rows x 386 columns]

# %%
df_count.plot(kind='bar', stacked=True, legend=False)
# Out:
# <Axes: xlabel='year'>

# %% [markdown]
# #### Дізнаємось кількість деталей по роках

# %%
pd.pivot_table(sets[['year', 'num_parts']], index = 'year', aggfunc = 'mean').plot(kind = 'bar')
# Out:
# <Axes: xlabel='year'>

# %%
sns.lmplot(x='year', y='num_parts', scatter=False, data=sets[['year', 'num_parts']])
sns.lineplot(x='year', y='num_parts',  data=sets[['year', 'num_parts']], legend=False)
# Out:
# <Axes: xlabel='year', ylabel='num_parts'>

# %% [markdown]
# #### дізнаємось приорітетні кольори по роках

# %% [markdown]
# Задача: дізнатись, які кольори фрагментів лего, були переважаючими у різні роки

# %%
Image(url="Screenshot at Jun 06 16-53-46.png", width=800, height=500,)
#https://www.python-graph-gallery.com/
# Out:
# <img src="Screenshot at Jun 06 16-53-46.png" width="800" height="500"/>

# %%
colors_df = pd.read_csv('lego/colors.csv')
inventory_parts_df =  pd.read_csv('lego/inventory_parts.csv')
inventories_df = pd.read_csv('lego/inventories.csv')

# %%
df = inventory_parts_df.merge(colors_df, how = 'left', left_on = 'color_id', right_on = 'id')

# %%
df
# Out:
#         inventory_id     part_num  color_id  quantity is_spare  id  \
# 0                  1     48379c01        72         1        f  72
# 1                  1        48395         7         1        f   7
# 2                  1     mcsport6        25         1        f  25
# 3                  1       paddle         0         1        f   0
# 4                  3  11816pr0005        78         1        f  78
# ...              ...          ...       ...       ...      ...  ..
# 580246         18708        99206         0         3        f   0
# 580247         18708        99207        71         4        f  71
# 580248         18708        99780        15         4        f  15
# 580249         18708        99780         0         9        f   0
# 580250         18708        99780        72         5        f  72
#
#                      name     rgb is_trans
# 0        Dark Bluish Gray  6C6E68        f
# 1              Light Gray  9BA19D        f
# 2                  Orange  FE8A18        f
# 3                   Black  05131D        f
# 4             Light Flesh  F6D7B3        f
# ...                   ...     ...      ...
# 580246              Black  05131D        f
# 580247  Light Bluish Gray  A0A5A9        f
# 580248              White  FFFFFF        f
# 580249              Black  05131D        f
# 580250   Dark Bluish Gray  6C6E68        f
#
# [580251 rows x 9 columns]

# %%
df = df.merge(inventories_df, how = 'left', left_on = 'inventory_id', right_on = 'id')

# %%
df
# Out:
#         inventory_id     part_num  color_id  quantity is_spare  id_x  \
# 0                  1     48379c01        72         1        f    72
# 1                  1        48395         7         1        f     7
# 2                  1     mcsport6        25         1        f    25
# 3                  1       paddle         0         1        f     0
# 4                  3  11816pr0005        78         1        f    78
# ...              ...          ...       ...       ...      ...   ...
# 580246         18708        99206         0         3        f     0
# 580247         18708        99207        71         4        f    71
# 580248         18708        99780        15         4        f    15
# 580249         18708        99780         0         9        f     0
# 580250         18708        99780        72         5        f    72
#
#                      name     rgb is_trans   id_y  version  set_num
# 0        Dark Bluish Gray  6C6E68        f      1        1   7922-1
# 1              Light Gray  9BA19D        f      1        1   7922-1
# 2                  Orange  FE8A18        f      1        1   7922-1
# 3                   Black  05131D        f      1        1   7922-1
# 4             Light Flesh  F6D7B3        f      3        1   3931-1
# ...                   ...     ...      ...    ...      ...      ...
# 580246              Black  05131D        f  18708        1  75090-2
# 580247  Light Bluish Gray  A0A5A9        f  18708        1  75090-2
# 580248              White  FFFFFF        f  18708        1  75090-2
# 580249              Black  05131D        f  18708        1  75090-2
# 580250   Dark Bluish Gray  6C6E68        f  18708        1  75090-2
#
# [580251 rows x 12 columns]

# %%
df = df.merge(sets, how = 'left', on = 'set_num')

# %%
df
# Out:
#         inventory_id     part_num  color_id  quantity is_spare  id_x  \
# 0                  1     48379c01        72         1        f    72
# 1                  1        48395         7         1        f     7
# 2                  1     mcsport6        25         1        f    25
# 3                  1       paddle         0         1        f     0
# 4                  3  11816pr0005        78         1        f    78
# ...              ...          ...       ...       ...      ...   ...
# 580246         18708        99206         0         3        f     0
# 580247         18708        99207        71         4        f    71
# 580248         18708        99780        15         4        f    15
# 580249         18708        99780         0         9        f     0
# 580250         18708        99780        72         5        f    72
#
#                    name_x     rgb is_trans   id_y  version  set_num  \
# 0        Dark Bluish Gray  6C6E68        f      1        1   7922-1
# 1              Light Gray  9BA19D        f      1        1   7922-1
# 2                  Orange  FE8A18        f      1        1   7922-1
# 3                   Black  05131D        f      1        1   7922-1
# 4             Light Flesh  F6D7B3        f      3        1   3931-1
# ...                   ...     ...      ...    ...      ...      ...
# 580246              Black  05131D        f  18708        1  75090-2
# 580247  Light Bluish Gray  A0A5A9        f  18708        1  75090-2
# 580248              White  FFFFFF        f  18708        1  75090-2
# 580249              Black  05131D        f  18708        1  75090-2
# 580250   Dark Bluish Gray  6C6E68        f  18708        1  75090-2
#
#                                                    name_y  year theme_id  \
# 0       McDonald's Sports Set Number 6 - Orange Vest S...  2004      460
# 1       McDonald's Sports Set Number 6 - Orange Vest S...  2004      460
# 2       McDonald's Sports Set Number 6 - Orange Vest S...  2004      460
# 3       McDonald's Sports Set Number 6 - Orange Vest S...  2004      460
# 4                                      Emma's Splash Pool  2012      494
# ...                                                   ...   ...      ...
# 580246                                Ezra's Speeder Bike  2015      182
# 580247                                Ezra's Speeder Bike  2015      182
# 580248                                Ezra's Speeder Bike  2015      182
# 580249                                Ezra's Speeder Bike  2015      182
# 580250                                Ezra's Speeder Bike  2015      182
#
#         num_parts
# 0               4
# 1               4
# 2               4
# 3               4
# 4              43
# ...           ...
# 580246        253
# 580247        253
# 580248        253
# 580249        253
# 580250        253
#
# [580251 rows x 16 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 580251 entries, 0 to 580250
# Data columns (total 16 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   inventory_id  580251 non-null  int64
#  1   part_num      580251 non-null  object
#  2   color_id      580251 non-null  int64
#  3   quantity      580251 non-null  int64
#  4   is_spare      580251 non-null  object
#  5   id_x          580251 non-null  int64
#  6   name_x        580251 non-null  object
#  7   rgb           580251 non-null  object
#  8   is_trans      580251 non-null  object
#  9   id_y          580251 non-null  int64
#  10  version       580251 non-null  int64
#  11  set_num       580251 non-null  object
#  12  name_y        580251 non-null  object
#  13  year          580251 non-null  int64
#  14  theme_id      580251 non-null  object
#  15  num_parts     580251 non-null  int64
# dtypes: int64(8), object(8)
# memory usage: 70.8+ MB

# %%
df[['inventory_id']] = df[['inventory_id']].astype(str)
df[['part_num']] = df[['part_num']].astype(str)

# %%
df[['inventory_id', 'part_num']].describe()
# Out:
#        inventory_id part_num
# count        580251   580251
# unique        10724    23131
# top            1305     6141
# freq            769    16550

# %%
df[['name_x', 'year']].describe()
# Out:
#                 year
# count  580251.000000
# mean     2005.695068
# std        10.860828
# min      1950.000000
# 25%      2000.000000
# 50%      2009.000000
# 75%      2014.000000
# max      2017.000000

# %%
df[['name_x', 'year']]
df = df.groupby(['year', 'name_x']).size().reset_index(name='counts')

# %%
df.sort_values(['year', 'counts'])
# Out:
#       year             name_x  counts
# 1     1950       Bright Green       2
# 3     1950        Light Green       2
# 4     1950        Medium Blue       2
# 5     1950      Medium Orange       2
# 7     1950        Trans-Clear       2
# ...    ...                ...     ...
# 2058  2017                Red    1345
# 2079  2017              White    2935
# 2027  2017   Dark Bluish Gray    3020
# 2043  2017  Light Bluish Gray    3888
# 2016  2017              Black    4940
#
# [2083 rows x 3 columns]

# %%
df = df.sort_values(['year', 'counts'])

# %%
sns.heatmap(df.pivot_table(index = 'name_x', columns = 'year', aggfunc = 'sum'))
# Out:
# <Axes: xlabel='None-year', ylabel='name_x'>

# %%
pivoted_df = df.pivot_table(index = 'name_x', columns = 'year', aggfunc = 'sum')

# %%
pivoted_df
# Out:
#                 counts                                                       \
# year              1950 1953  1954  1955  1956  1957   1958 1959  1960  1961
# name_x
# Aqua               NaN  NaN   NaN   NaN   NaN   NaN    NaN  NaN   NaN   NaN
# Black              NaN  NaN   NaN   NaN   NaN   1.0   14.0  NaN   6.0   1.0
# Blue               6.0  1.0  13.0  18.0   NaN  14.0   26.0  5.0  11.0  20.0
# Blue-Violet        NaN  NaN   NaN   NaN   NaN   NaN    NaN  NaN   NaN   NaN
# Bright Green       2.0  NaN   NaN   NaN   NaN   NaN    NaN  NaN   NaN   NaN
# ...                ...  ...   ...   ...   ...   ...    ...  ...   ...   ...
# Violet             NaN  NaN   NaN   NaN   NaN   NaN    NaN  NaN   NaN   NaN
# White              8.0  6.0  28.0  93.0  52.0  74.0  181.0  1.0  28.0  63.0
# Yellow             8.0  3.0  16.0  19.0   NaN   1.0   12.0  3.0   7.0   7.0
# Yellowish Green    NaN  NaN   NaN   NaN   NaN   NaN    NaN  NaN   NaN   NaN
# [No Color]         NaN  NaN   NaN   1.0   1.0   1.0    NaN  NaN   1.0   1.0
#
#                  ...                                                          \
# year             ...    2008    2009    2010    2011    2012    2013    2014
# name_x           ...
# Aqua             ...     NaN     NaN     NaN     NaN     NaN     1.0     NaN
# Black            ...  4404.0  4467.0  4372.0  4541.0  5136.0  5975.0  7344.0
# Blue             ...  1002.0  1029.0  1165.0   995.0  1095.0  1105.0  1391.0
# Blue-Violet      ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# Bright Green     ...    41.0    22.0    70.0    73.0   214.0   195.0   249.0
# ...              ...     ...     ...     ...     ...     ...     ...     ...
# Violet           ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# White            ...  2820.0  2421.0  2958.0  2919.0  2999.0  3730.0  4067.0
# Yellow           ...  1148.0  1568.0  1372.0  1399.0  1746.0  1599.0  1669.0
# Yellowish Green  ...     NaN     NaN     NaN     NaN     3.0     NaN    14.0
# [No Color]       ...    58.0    48.0    43.0   200.0   213.0   164.0    50.0
#
#
# year               2015    2016    2017
# name_x
# Aqua                NaN     6.0     1.0
# Black            8057.0  8613.0  4940.0
# Blue             1557.0  1619.0   835.0
# Blue-Violet         NaN     NaN     NaN
# Bright Green      225.0   237.0    85.0
# ...                 ...     ...     ...
# Violet              NaN     NaN     NaN
# White            4786.0  4738.0  2935.0
# Yellow           2076.0  2029.0   950.0
# Yellowish Green   108.0    28.0    39.0
# [No Color]         40.0    80.0    30.0
#
# [131 rows x 66 columns]

# %%
# Розрахуємо суму по рядкам і додаємо її як нову колонку 'row_sum'
pivoted_df['row_sum'] = pivoted_df.sum(axis=1)

# Сортуємо мультиіндексний датафрейм по цій колонці в спадному порядку
pivoted_df= pivoted_df.sort_values('row_sum')

# Якщо вам не потрібна колонка 'row_sum', ви можете видалити її
pivoted_df= pivoted_df.drop(columns=['row_sum'])

# %%
pivoted_df
# Out:
#                        counts                                                 \
# year                     1950 1953  1954  1955  1956  1957   1958 1959  1960
# name_x
# Trans Light Royal Blue    NaN  NaN   NaN   NaN   NaN   NaN    NaN  NaN   NaN
# Medium Violet             NaN  NaN   NaN   NaN   NaN   NaN    NaN  NaN   NaN
# Very Light Orange         NaN  NaN   NaN   NaN   NaN   NaN    NaN  NaN   NaN
# Chrome Green              NaN  NaN   NaN   NaN   NaN   NaN    NaN  NaN   NaN
# Very Light Gray           NaN  NaN   NaN   NaN   NaN   NaN    NaN  NaN   NaN
# ...                       ...  ...   ...   ...   ...   ...    ...  ...   ...
# Dark Bluish Gray          NaN  NaN   NaN   NaN   NaN   NaN    NaN  NaN   NaN
# Red                       8.0  5.0  35.0  53.0  20.0  53.0   56.0  7.0  10.0
# Light Bluish Gray         NaN  NaN   NaN   NaN   NaN   NaN    NaN  NaN   NaN
# White                     8.0  6.0  28.0  93.0  52.0  74.0  181.0  1.0  28.0
# Black                     NaN  NaN   NaN   NaN   NaN   1.0   14.0  NaN   6.0
#
#                               ...                                          \
# year                    1961  ...    2008    2009    2010    2011    2012
# name_x                        ...
# Trans Light Royal Blue   NaN  ...     NaN     NaN     NaN     NaN     NaN
# Medium Violet            NaN  ...     NaN     NaN     NaN     NaN     NaN
# Very Light Orange        NaN  ...     NaN     NaN     NaN     NaN     NaN
# Chrome Green             NaN  ...     NaN     NaN     NaN     NaN     NaN
# Very Light Gray          NaN  ...     NaN     NaN     NaN     NaN     NaN
# ...                      ...  ...     ...     ...     ...     ...     ...
# Dark Bluish Gray         NaN  ...  2731.0  2565.0  2738.0  2649.0  3433.0
# Red                     41.0  ...  1415.0  1888.0  2089.0  2016.0  2087.0
# Light Bluish Gray        NaN  ...  3113.0  3252.0  3337.0  3380.0  4303.0
# White                   63.0  ...  2820.0  2421.0  2958.0  2919.0  2999.0
# Black                    1.0  ...  4404.0  4467.0  4372.0  4541.0  5136.0
#
#
# year                      2013    2014    2015    2016    2017
# name_x
# Trans Light Royal Blue     NaN     NaN     NaN     NaN     NaN
# Medium Violet              NaN     NaN     NaN     NaN     NaN
# Very Light Orange          NaN     NaN     NaN     NaN     NaN
# Chrome Green               NaN     NaN     NaN     NaN     NaN
# Very Light Gray            NaN     NaN     NaN     NaN     NaN
# ...                        ...     ...     ...     ...     ...
# Dark Bluish Gray        3733.0  4679.0  5355.0  5433.0  3020.0
# Red                     2221.0  2332.0  2464.0  2769.0  1345.0
# Light Bluish Gray       4693.0  6235.0  7005.0  6965.0  3888.0
# White                   3730.0  4067.0  4786.0  4738.0  2935.0
# Black                   5975.0  7344.0  8057.0  8613.0  4940.0
#
# [131 rows x 66 columns]

# %%
sns.set(rc={'figure.figsize':(11,20)})
sns.heatmap(pivoted_df)
# Out:
# <Axes: xlabel='None-year', ylabel='name_x'>

# %%
df
# Out:
#       year             name_x  counts
# 1     1950       Bright Green       2
# 3     1950        Light Green       2
# 4     1950        Medium Blue       2
# 5     1950      Medium Orange       2
# 7     1950        Trans-Clear       2
# ...    ...                ...     ...
# 2058  2017                Red    1345
# 2079  2017              White    2935
# 2027  2017   Dark Bluish Gray    3020
# 2043  2017  Light Bluish Gray    3888
# 2016  2017              Black    4940
#
# [2083 rows x 3 columns]

# %%
sns.scatterplot(data=df, x="year", y="name_x", size="counts", legend=False, sizes=(20, 2000))
# Out:
# <Axes: xlabel='year', ylabel='name_x'>
